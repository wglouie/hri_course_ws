# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("wrongpath.jpg")

# %%
print(img)
# Out:
# None

# %%
type(img)
# Out:
# NoneType

# %%
img_bgr = cv2.imread('./data/puppy.jpg')

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img)
